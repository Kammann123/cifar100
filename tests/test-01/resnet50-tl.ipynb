# %% [markdown]
# # Fuentes
#
# ### Link: https://towardsdatascience.com/simple-image-data-augmentation-technics-to-mitigate-overfitting-in-computer-vision-2a6966f51af4
# Explicación general sobre técnicas de **data augmentation** orientadas a conjuntos de datos de imágenes.
#
# ### Link: https://albumentations.ai/docs/getting_started/image_augmentation/
# Página oficial de la biblioteca **Albumentations**, utilizada para crear pipelines con operaciones aleatorias a realizar sobre las imágenes para generar un conjunto de datos más grande.
#
# ### Link: https://medium.com/the-artificial-impostor/custom-image-augmentation-with-keras-70595b01aeac
# Es interesante observar cómo se puede hacer aplicar data augmentation 'on the fly' sobre cada batch, para evitar que el conjunto de datos crezca demasiado en memoria y que no pueda manejarse.

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import albumentations as A

# %%
sns.set(style='darkgrid', context='notebook')

# %% [markdown]
# ## Cargando las bases de datos

# %%
x_train_valid = np.load('../input/cifar100-nn-competition/x_train.npy')
y_train_valid = np.load('../input/cifar100-nn-competition/y_train.npy')
x_test = np.load('../input/cifar100-nn-competition/x_test.npy')

# %% [markdown]
# # Preprocesamiento de entradas para ResNet50

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
x_train_valid = preprocess_input(x_train_valid)
x_test = preprocess_input(x_test)

# %% [markdown]
# # Separando conjuntos para entrenamiento y validación

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train_valid, y_train_valid, test_size=0.2, random_state=15, stratify=y_train_valid)

# %% [markdown]
# # Data Augmentation with Albumentation
# Se aplica **data augmentation** utilizando la biblioteca Albumentations para aumentar el tamaño del conjunto de datos para entrenamiento. El conjunto de validación permanece intacto para validar que la técnica tuvo buenos resultados sin contaminar los datos de dicho conjunto.

# %%
from tensorflow.keras.utils import Sequence

# %%
from albumentations import Compose, ToFloat, HorizontalFlip, VerticalFlip, Rotate, RandomSizedCrop, ShiftScaleRotate, GridDistortion
from albumentations import ElasticTransform, RandomBrightnessContrast

# %%
class AugmentedSequence(Sequence):
  """ Dataset generator with data augmentation """

  def __init__(self, x, y, batch_size, augmentation, shuffle=True):
    """ Create an instance of the data augmented generator, which is a 
        dataset generator to provide 'on the fly' data augmentation.
        @param x
        @param y
        @param batch_size
        @param augmentation
        @param shuffle
    """
    # Save internal parameters of the augmented sequence
    self.x = x
    self.y = y
    self.batch_size = batch_size
    self.augmentation = augmentation
    self.shuffle = shuffle

    # Initialization
    self.on_epoch_end()
  
  def __len__(self):
    """ Compute the length of an epoch measured in batches
    """
    return int(np.floor(len(self.x) / float(self.batch_size)))
  
  def __getitem__(self, index):
    """ Return the item from the sequence at the given index
        @param index
    """
    # Generate indexes of the batch
    indexes = self.indexes[index * self.batch_size : (index + 1) * self.batch_size]

    # Extract the input and output batch from the original dataset
    batch_x = self.x[indexes]
    batch_y = self.y[indexes]
    
    # Return an augmented version of the batch
    return np.array([
      self.augmentation(image=x)['image'] for x in batch_x
    ]), np.array(batch_y)

  def on_epoch_end(self):
    """ Updates indexes after each epoch
    """
    self.indexes = np.arange(len(self.x))
    if self.shuffle is True:
        np.random.shuffle(self.indexes)

# %%
# Create the AugmentedSequence
album_generator = AugmentedSequence(x_train,
                                    y_train,
                                    40000,
                                    Compose([
                                        ShiftScaleRotate(shift_limit=0.1,
                                                         scale_limit=0.2,
                                                         rotate_limit=30,
                                                         p=0.5),
                                        HorizontalFlip(p=0.5),
                                        VerticalFlip(p=0.5),
                                        GridDistortion(p=0.2),
                                        ElasticTransform(p=0.2),
                                        RandomBrightnessContrast(p=0.2)
                                        ])
                                    )

# %% [markdown]
# # Modelos

# %%
from tensorflow.keras.layers import Dense, Flatten, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, InputLayer, AveragePooling2D, Input, UpSampling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow import keras

# %% [markdown]
# ## ResNet 50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
# It's important to 
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256,256,3))

# %%
# Train weigths that contains batch normalization
for layer in resnet_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False # Originally, this was False!

# %%
# Create layers
model = Sequential()

# Performing upsampling to fit better imagenet images dimension
model.add(UpSampling2D())
model.add(UpSampling2D())
model.add(UpSampling2D())

# Loading ResNet Model.
model.add(resnet_model)

# GlobalAVGPooling outputs 1x1?
model.add(GlobalAveragePooling2D())
model.add(BatchNormalization()) # This is new also

# Fully connected network
# Layer 1
model.add(Dense(units=1024))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(Dropout(0.4))

# Layer 2
model.add(Dense(units=1024))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(Dropout(0.4))

# Softmax layer
model.add(Dense(units=100))
model.add(BatchNormalization())
model.add(Activation('softmax'))


# Compile
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy']
             )

# %%
# Create the ModelCheckpoint callback to save the best model during training
mc_callback = ModelCheckpoint('model_res50.hdf5',
                              monitor='val_accuracy',
                              save_best_only=True,
                              verbose=0,
                              mode='max'
                             )

# Train the model
epochs = 5
batch_size = 64
augmented_factor = 11
for i in range(augmented_factor):
    print(f'******** Iteration {i+1} of {augmented_factor+1} ********')
    batch_x, batch_y = album_generator[0]
    model.fit(batch_x,
            batch_y, 
            validation_data=(x_valid, y_valid), 
            callbacks=[mc_callback],
            batch_size=batch_size,
            epochs=epochs
            )
# Out:
# ******** Iteration 1 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 201s 313ms/step - loss: 3.8665 - accuracy: 0.1436 - val_loss: 1.7578 - val_accuracy: 0.5499
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.9109 - accuracy: 0.3167 - val_loss: 1.3775 - val_accuracy: 0.6295
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.6211 - accuracy: 0.3753 - val_loss: 1.2375 - val_accuracy: 0.6564
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.4249 - accuracy: 0.4114 - val_loss: 1.1470 - val_accuracy: 0.6799
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.2622 - accuracy: 0.4421 - val_loss: 1.0939 - val_accuracy: 0.6917
# ******** Iteration 2 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.4691 - accuracy: 0.3925 - val_loss: 1.0119 - val_accuracy: 0.7099
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.3023 - accuracy: 0.4254 - val_loss: 0.9882 - val_accuracy: 0.7146
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.1698 - accuracy: 0.4541 - val_loss: 0.9772 - val_accuracy: 0.7148
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.0740 - accuracy: 0.4790 - val_loss: 0.9700 - val_accuracy: 0.7143
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.9854 - accuracy: 0.4937 - val_loss: 0.9576 - val_accuracy: 0.7202
# ******** Iteration 3 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.2768 - accuracy: 0.4344 - val_loss: 0.9176 - val_accuracy: 0.7279
# Epoch 2/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.1235 - accuracy: 0.4638 - val_loss: 0.8936 - val_accuracy: 0.7402
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 2.0222 - accuracy: 0.4858 - val_loss: 0.9004 - val_accuracy: 0.7365
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.9322 - accuracy: 0.5056 - val_loss: 0.9034 - val_accuracy: 0.7386
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.8489 - accuracy: 0.5242 - val_loss: 0.9090 - val_accuracy: 0.7378
# ******** Iteration 4 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.1796 - accuracy: 0.4527 - val_loss: 0.8659 - val_accuracy: 0.7440
# Epoch 2/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.0173 - accuracy: 0.4887 - val_loss: 0.8651 - val_accuracy: 0.7449
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.9213 - accuracy: 0.5099 - val_loss: 0.8767 - val_accuracy: 0.7467
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.8455 - accuracy: 0.5238 - val_loss: 0.8740 - val_accuracy: 0.7454
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7542 - accuracy: 0.5462 - val_loss: 0.8812 - val_accuracy: 0.7445
# ******** Iteration 5 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.1088 - accuracy: 0.4711 - val_loss: 0.8372 - val_accuracy: 0.7484
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.9503 - accuracy: 0.5053 - val_loss: 0.8298 - val_accuracy: 0.7555
# Epoch 3/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.8481 - accuracy: 0.5275 - val_loss: 0.8470 - val_accuracy: 0.7550
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7674 - accuracy: 0.5461 - val_loss: 0.8528 - val_accuracy: 0.7551
# Epoch 5/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.6954 - accuracy: 0.5590 - val_loss: 0.8632 - val_accuracy: 0.7507
# ******** Iteration 6 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 2.0407 - accuracy: 0.4879 - val_loss: 0.8204 - val_accuracy: 0.7622
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.8995 - accuracy: 0.5171 - val_loss: 0.8231 - val_accuracy: 0.7596
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7956 - accuracy: 0.5404 - val_loss: 0.8314 - val_accuracy: 0.7600
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7238 - accuracy: 0.5556 - val_loss: 0.8425 - val_accuracy: 0.7586
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6407 - accuracy: 0.5736 - val_loss: 0.8522 - val_accuracy: 0.7532
# ******** Iteration 7 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.9857 - accuracy: 0.4999 - val_loss: 0.8067 - val_accuracy: 0.7635
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.8367 - accuracy: 0.5335 - val_loss: 0.8074 - val_accuracy: 0.7658
# Epoch 3/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.7514 - accuracy: 0.5542 - val_loss: 0.8109 - val_accuracy: 0.7639
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6681 - accuracy: 0.5710 - val_loss: 0.8230 - val_accuracy: 0.7582
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5912 - accuracy: 0.5855 - val_loss: 0.8348 - val_accuracy: 0.7587
# ******** Iteration 8 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.9638 - accuracy: 0.5066 - val_loss: 0.7985 - val_accuracy: 0.7676
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.8211 - accuracy: 0.5374 - val_loss: 0.7881 - val_accuracy: 0.7692
# Epoch 3/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.7244 - accuracy: 0.5587 - val_loss: 0.8063 - val_accuracy: 0.7678
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6449 - accuracy: 0.5768 - val_loss: 0.8117 - val_accuracy: 0.7653
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5677 - accuracy: 0.5928 - val_loss: 0.8239 - val_accuracy: 0.7661
# ******** Iteration 9 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.9145 - accuracy: 0.5182 - val_loss: 0.7762 - val_accuracy: 0.7700
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7732 - accuracy: 0.5481 - val_loss: 0.7677 - val_accuracy: 0.7739
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6764 - accuracy: 0.5727 - val_loss: 0.7845 - val_accuracy: 0.7729
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5990 - accuracy: 0.5863 - val_loss: 0.7984 - val_accuracy: 0.7695
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5252 - accuracy: 0.6047 - val_loss: 0.8046 - val_accuracy: 0.7680
# ******** Iteration 10 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.8836 - accuracy: 0.5272 - val_loss: 0.7651 - val_accuracy: 0.7726
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7412 - accuracy: 0.5574 - val_loss: 0.7704 - val_accuracy: 0.7760
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6412 - accuracy: 0.5790 - val_loss: 0.7841 - val_accuracy: 0.7717
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5691 - accuracy: 0.5982 - val_loss: 0.7928 - val_accuracy: 0.7746
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.4897 - accuracy: 0.6169 - val_loss: 0.8117 - val_accuracy: 0.7707
# ******** Iteration 11 of 12 ********
# Epoch 1/5
# 625/625 [==============================] - 194s 311ms/step - loss: 1.8679 - accuracy: 0.5339 - val_loss: 0.7578 - val_accuracy: 0.7793
# Epoch 2/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.7232 - accuracy: 0.5615 - val_loss: 0.7581 - val_accuracy: 0.7803
# Epoch 3/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.6367 - accuracy: 0.5814 - val_loss: 0.7768 - val_accuracy: 0.7748
# Epoch 4/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.5551 - accuracy: 0.6012 - val_loss: 0.7853 - val_accuracy: 0.7733
# Epoch 5/5
# 625/625 [==============================] - 194s 310ms/step - loss: 1.4791 - accuracy: 0.6181 - val_loss: 0.8033 - val_accuracy: 0.7716

# %%
# Load the model and show the final metrics
model = keras.models.load_model('model_res50.hdf5')

# Train and validation metrics
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
_, valid_acc = model.evaluate(x_valid, y_valid, verbose=0)

# Show result
print(f'[Accuracy] Train: {round(train_acc, 3)} Valid: {round(valid_acc, 3)}')
# Out:
# [Accuracy] Train: 0.889 Valid: 0.78

# %%
def generate_submission(predictions, filepath='submission.csv'):
    """ Generate the .csv file to submit in the challenge
        @param predictions Predictions made by the model from the test dataset
        @param filepath Filepath for the file generated
    """
    df = pd.DataFrame(predictions, columns=['label'])
    df.index.name = 'Id'
    df.to_csv(filepath)

# %%
import pandas as pd

# %%
# Predict over the test set
y_pred = model.predict(x_test).argmax(axis=-1)

# Save submission
generate_submission(y_pred, filepath='submission1.csv')
